# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2

# %%
def red_channel_method(red, green, blue):
    r = g = b = red
    return r, g, b

# %%
def green_channel_method(red, green, blue):
    r = g = b = green
    return r, g, b

# %%
def blue_channel_method(red, green, blue):
    r = g = b = blue
    return r, g, b

# %%
def max_rgb_method(red, green, blue):
    r = g = b = np.maximum(np.maximum(red, green), blue)
    return r, g, b

# %%
def min_rgb_method(red, green, blue):
    #here
    return

# %%
def lightness_method(red, green, blue):
    #here
    return

# %%
def average_method(red, green, blue):
    #here
    return

# %%
def luminosity_method(red, green, blue):
    #here
    return

# %%
def comparing(input_image, output_image):
    pass

# %%
# colored_image = img.imread("images/1.jpg")
# r_channel, g_channel, b_channel = colored_image[:, :, 0], colored_image[: , :, 1], colored_image[:, :, 2]
# new_r_channel, new_g_channel, new_b_channel = max_rgb_method(r_channel, g_channel, b_channel)
# grayscale_image = new_r_channel + new_g_channel + new_b_channel
# comparing(colored_image, grayscale_image)

colored_image = cv2.imread("images/2.jpg")
plt.imshow(colored_image)
plt.show()
b_channel, g_channel, r_channel = cv2.split(colored_image)
new_rch, new_gch, new_bch = red_channel_method(r_channel, g_channel, b_channel)
grayscale_image = cv2.merge([new_bch, new_gch, new_rch])
plt.imshow(grayscale_image)
plt.show()
new_rch, new_gch, new_bch = green_channel_method(r_channel, g_channel, b_channel)
grayscale_image = cv2.merge([new_bch, new_gch, new_rch])
plt.imshow(grayscale_image)
plt.show()
new_rch, new_gch, new_bch = blue_channel_method(r_channel, g_channel, b_channel)
grayscale_image = cv2.merge([new_bch, new_gch, new_rch])
plt.imshow(grayscale_image)
plt.show()
# cv2.imshow("Colored Image", colored_image)
# cv2.imshow("GrayScale Image", grayscale_image)
